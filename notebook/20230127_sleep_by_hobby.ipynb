# %%
import pandas as pd
d2 = pd.read_csv('./data/sleep_by_hobby.csv')
# Out:
#       hobby  sleep
# 0      game      5
# 1      game      6
# 2      game      3
# 3      game      2
# 4   fishing      7
# 5   fishing      5
# 6   fishing      4
# 7   fishing      4
# 8    soccer     12
# 9    soccer     10
# 10   soccer      8
# 11   soccer      6

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.violinplot(x='hobby', y='sleep',data=d2)
plt.show()

# %%
d2.groupby('hobby').mean()
# Out:
#          sleep
# hobby
# fishing    5.0
# game       4.0
# soccer     9.0

# %%
import statsmodels.api as sma
from statsmodels.formula.api import ols

anova = ols('sleep~hobby',data=d2).fit()

# %%
anova.summary()
# Out:
# C:\Users\kawam\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sleep   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     7.000
# Date:                Fri, 27 Jan 2023   Prob (F-statistic):             0.0147
# Time:                        13:22:39   Log-Likelihood:                -23.619
# No. Observations:                  12   AIC:                             53.24
# Df Residuals:                       9   BIC:                             54.69
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
#線形回帰分析

# %%
import numpy as np
import pandas as pd

m_d = pd.read_csv('./data/Mansion1.csv')
m_d
# Out:
#     distance    rent floorPlan  space direction  age
# 0          B   68000        1K     19         西   12
# 1          B   68000        1K     19         南   12
# 2          B   69000        1K     19        北西   14
# 3          B   70000        1K     19         南   14
# 4          B   72000        1K     15         南    9
# ..       ...     ...       ...    ...       ...  ...
# 135        B  145000       1DK     40         南    8
# 136        B  145000     1SLDK     54        南東   28
# 137        A  148000      1LDK     42        南東   13
# 138        A  148000      1LDK     42         南   13
# 139        B  150000      1LDK     41        南東    5
#
# [140 rows x 6 columns]

# %%
sns.pairplot(m_d, hue='floorPlan')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#相関係数
#ageとrentが正の相関なので、注目
m_d.corr()
# Out:
#            rent     space       age
# rent   1.000000  0.841193  0.245452
# space  0.841193  1.000000  0.515945
# age    0.245452  0.515945  1.000000

# %%
m_d.groupby('floorPlan').corr()
#floorplanで切ると、rentとageが負の相関
#均等ではない
# Out:
#                      rent     space       age
# floorPlan
# 1DK       rent   1.000000  0.830696 -0.424088
#           space  0.830696  1.000000 -0.050928
#           age   -0.424088 -0.050928  1.000000
# 1K        rent   1.000000  0.807431 -0.373257
#           space  0.807431  1.000000 -0.270430
#           age   -0.373257 -0.270430  1.000000
# 1LDK      rent   1.000000  0.924388 -0.058448
#           space  0.924388  1.000000 -0.319551
#           age   -0.058448 -0.319551  1.000000
# 1R        rent   1.000000  0.526474 -0.511962
#           space  0.526474  1.000000 -0.338708
#           age   -0.511962 -0.338708  1.000000
# 1SLDK     rent        NaN       NaN       NaN
#           space       NaN       NaN       NaN
#           age         NaN       NaN       NaN
# 2DK       rent   1.000000  0.470572 -0.265519
#           space  0.470572  1.000000 -0.601921
#           age   -0.265519 -0.601921  1.000000
# 2K        rent        NaN       NaN       NaN
# ...

# %%
m_d['floorPlan'].value_counts()
# Out:
# 1K       105
# 1R         9
# 2DK        9
# 1LDK       8
# 1DK        6
# 2K         1
# 2LDK       1
# 1SLDK      1
# Name: floorPlan, dtype: int64

# %%
m_d['distance'].value_counts()
# Out:
# B    71
# A    69
# Name: distance, dtype: int64

# %%
m_d['direction'].value_counts()
# Out:
# 南     37
# 南東    33
# 東     23
# 西     21
# 南西    14
# 北西     6
# 北東     5
# 北      1
# Name: direction, dtype: int64
