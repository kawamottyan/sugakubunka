# %% [markdown]
# # 3　サポートベクトルマシン
# サポートベクトルマシン(SVM)という分類器について解説します．まずは最も基本的な線形SVMの仕組みを見ていきましょう．
#
# 線形SVMには，
#  * 線形2値分類の手法(カーネル法を用いることで非線形分類も可能)
#  * 外れ値に影響されにくい(サポートベクトルで判別器が決まる)
#
# という特徴があります．
#
# 同じ線形分類の手法であるロジスティック回帰などとの違いは，データがうまく分離されていることを，マージンと呼ばれる量によって測っていることです．

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# ## A　線形SVMの仮定
# 簡単のため，説明変数を$x_1, x_2$としましょう．
#
# SVMによる2値分類では次のように問題を設定します．
#
#  * 目的変数$y$は1または-1とする(「0または1」，「1または2」などにはしない)．
#
#  * $f(x_1, x_2) = w_1x_1 + w_2x_2 + b$とおいて，$f(x_1, x_2)\geqq 0$のとき$y=1$，$f(x_1, x_2)<0$のとき$y=-1$と判別する．
#
# このように定めておくことで，正しく判別できていることは$y(w_1x_1 + w_2x_2 + b) \geqq 0$と表すことができます．

# %% [markdown]
# ## B　ハードマージンSVM
#
# SVMではマージン最大化という基準で，訓練データを最もよく判別できるように$w_1, w_2, b$の値を求めます．
#
#
#  * マージン :  判別境界の周りにデータポイントが存在しない帯状の領域
#  * サポートベクトル : マージンの境界上のデータポイント
#  * マージンの大きさ :　判別境界からサポートベクトルまでの距離(点と直線の距離)
#
# この状況を図示すると次のようになります．
#
# マージンの大きさが最大となるように判別境界を設定するのがSVMです．つまり次のような境界線は引かれません．
#
# これはSVMの仕組みが正則化を含んでいることを意味します．

# %% [markdown]
# #### 点と直線の距離の公式
# マージンの大きさを計算するために，点と直線の距離の公式を復習しておきましょう．
# 点$(x_1, x_2)$から直線$w_1x_1 + w_2x_2 + b=0$に下した垂線の長さを，この点と直線間の距離といいます．
#
# この値は，
# $$\displaystyle \frac{|w_1x_1 + w_2x_2 + b|}{\sqrt{w_1^2+w_2^2}}$$
# で求められることが知られています．

# %%
#点の座標と直線の係数を入力
x = np.array([2,4])
w1 = 1
w2 = 1
b = -5


intercept = np.array([[-b/w1, 0],[0, -b/w2]]) #切片を計算


plt.scatter(x[0],x[1])
plt.plot(intercept[:,0],intercept[:,1])

plt.show()

# %%
#点と直線の距離
np.abs(w1*x[0]+w2*x[1]+b)/np.sqrt(w1**2+w2**2)
# Out:
# 0.7071067811865475

# %% [markdown]
# ## B　「マージン最大化」の数式による表現
#
# $w_1,w_2, b$の値に同じ定数$(\not=0)$をかけても直線は変わりません．よって点と直線の距離の計算結果も変わりません．
#
# ところが，$f(w_1, w_2) = w_1x_1 + w_2x_2 + b$の値はかけた定数倍の分変化します．
# このことから，必要があれば係数を定数倍変更することによって，
#
#  * データポイントがサポートベクトルであることは$y(w_1 x_1 + w_2x_2 + b) = 1$ と表せる．
#  * データポイントがマージンの外側にあることは$y(w_1 x_1 + w_2x_2 + b) \geqq 1$と表せる．
#
# とすることができます．
# また，このとき，
#
#  * マージンの大きさは$\displaystyle \frac{1}{\sqrt{w_1^2 +w_2^2}}$と表せる．
#
# ということもわかります．
#
# $\displaystyle \frac{1}{\sqrt{w_1^2 +w_2^2}}$の最大化は$w_1^2 +w_2^2$の最小化と同値であることにも注意しましょう．
#
# 以上をまとめると，マージンの最大化は，
#
# 条件「各データポイントiについて$y(w_1 x_{1i} + w_2x_{2i} + b) \geqq 1$が満たされる」 の下，$w_1^2 +w_2^2$の最小化
#
# と表現することができます．SVMの学習とは数学的にはこの条件付き最小値問題を解くことに他なりません．

# %% [markdown]
# ## C　スラック変数とソフトマージンの導入
# 以上のSVMの基礎となる考え方をハードマージンといいます．しかし，ハードマージンを採用してしまうと線形分離不能な訓練データについては解なしとなってしまいます．
#
# 線形分離不能な場合でも，不能なりになるべく良い直線を引くための工夫がスラック変数の導入です．
#
# スラック変数の導入によってマージン内へのデータの侵入や誤判別を許したマージンをソフトマージンといいます．

# %% [markdown]
# #### スラック変数
# 各データポイントに対して，$\xi = \max\{0, 1-y(w_1x_1+w_2x_2+b)\}$をスラック変数といいます．
#
# これはデータポイントがマージン内に存在しないという条件をどれだけ違反しているかを測っているといえる量です．具体例を通してこのことを確認してみましょう．

# %% [markdown]
# **演習**　判別関数が$2x_1 + x_2 -6$であるとき，次の点(yは正解ラベル)について，
#
#  * スラック変数の値はいくつですか．
#  * サポートベクトルである点はどれですか．
#  * 散布図上の配置とスラック変数の値の関係について考えてみましょう．
#  * 各データに対して$y_i(w_1 x_{1i} + w_2x_{2i} + b) \geqq 1-\xi$が満たされていることを確認しましょう．
#
# (1) $(2,4), y = 1$<br>
# (2) $(3,0.5), y = 1$<br>
# (3) $(1,3), y = -1$<br>
# (4) $(1,4.5), y = -1$

# %%
#点の座標と直線の係数を入力
x = np.array([[2,4],[3,0.5],[1,3],[1,4.5]])
y = np.array([1,1,-1,-1])

w1, w2, b = 2, 1, -6


intercept = np.array([[-b/w1, 0],[0, -b/w2]]) #切片を計算

plt.scatter(x[[0,1],0],x[[0,1],1], c="red", label="y=1")
plt.scatter(x[[2,3],0],x[[2,3],1], c="green", label="y=-1")


plt.legend()

plt.plot(intercept[:,0],intercept[:,1])

plt.show()

# %% [markdown]
# ソフトマージンによるSVMによる学習とは，
#
#  * マージンを大きく = $w_1^2+w_2^2$を小さく
#  * 違反を小さく = $\xi$の合計を小さく
#
# の二つを同時に最適にする判別関数を求めることです．数学的に正確に述べると，
#
#
# 条件「各データポイントについて$y(w_1 x_1 + w_2x_2 + b) \geqq 1-\xi_i$が満たされる」 の下，$w_1^2 +w_2^2+C\sum \xi_i$の最小化
#
# となります．
# ここで，Cは負でない定数で，分析者が設定するハイパーパラメータです．Cが大きいほど違反に厳しくマージンが小さくなります(ハードマージンの状態に近づくともいえる)．
#
# 通常，SVMと言ったらソフトマージンを用いたSVMを指します．(以下，この資料でもそうします．)

# %% [markdown]
# ## D　ヒンジ損失
# SVMはヒンジ損失を損失関数としてL2正則化を施した識別機ということができます．このことについて順を追って説明します．

# %% [markdown]
# #### ヒンジ関数
# $hinge(x) = max(0, a-x)$をヒンジ関数といいます．a = 1の場合のグラフは次のようになります．

# %%
def hinge(x, a=1):
    return np.where(a-x > 0, a-x, 0)

# %%
x = np.linspace(start = -3.0, stop = 3.0, num = 100)
L = hinge(x)
plt.plot(x, L)
plt.show()

# %%
w1, w2, b = 2, 1, -6
x=np.array([1,3])
y = -1

hinge(y*(w1*x[0]+w2*x[1]+b))
# Out:
# array(0)

# %% [markdown]
# ヒンジ損失を導入するとSVMは，
#
# 各データポイントに対してヒンジ損失を計算し、その合計と罰則項の和
# $$J(w) = \sum_{i=1}^{n}hinge(y_i(w_1x_{1i}+w_2x_{2i}+b))+\lambda(w_1^2+w_2^2)$$
# をが最も小さくなるような1次式$f(x;w) = w_1x_1+w_2x_2+b$を予測器として求める手法
#
# ということができます．
# $\lambda(w_1^2+w_2^2)$はL2正則化を行っている項でマージン最大化に対応しています．
# $\lambda$は正則化の強さを決めるハイパーパラメータで正則化パラメータと呼ばれるものです．上で述べたCとは$C=\frac{1}{\lambda}$の関係があり，このことからCは逆正則化パラメータと呼ばれます．

# %% [markdown]
# ## E　sklearnによる実装
# サポートベクトルマシンはsklearn.svmモジュールのSVCクラスで実行できます．<br>
# 同じモジュール内にサポートベクトル回帰用のクラスSCRも含まれています．
#
# 逆正則化ハイパーパラメータは`C`という引数で指定できます。

# %%
# デモデータの生成
# 出力ラベルy = 0のデータを生成
X_train_0 = np.random.multivariate_normal(mean = [1, 1], 
                                          cov = [[1, -0.2], [-0.2, 1]], 
                                          size = 50)
y_train_0 = np.zeros(50)
# 出力ラベルy = 1のデータを生成
X_train_1 = np.random.multivariate_normal(mean = [-1, -1], 
                                          cov = [[1, -0.2], [-0.2, 1]], 
                                          size = 50)
y_train_1 = np.ones(50)
# 2種類のデータを結合する。
X_train = np.vstack((X_train_0, X_train_1))
y_train = np.hstack((y_train_0, y_train_1))

# %%
# データの可視化
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
# 入力を標準化する。
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)

# %%
from sklearn.svm import SVC

svc_l= SVC(C = 1.0, kernel = "linear")    # インスタンスを建てる。
svc_l.fit(X_train_sc, y_train)    # fitメソッド：学習させる。
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# テストデータの入力を生成し、実際に予測させる。
# 格子点上にデータを生成する。
xx, yy = np.meshgrid(
    np.linspace(start = -4.5, stop = 4.5, num = 100), 
    np.linspace(start = -4.5, stop = 4.5, num = 100))
X_test = np.c_[xx.ravel(), yy.ravel()]
# 入力の標準化
X_test_sc = sc.transform(X_test)    # 訓練時の標準化と同じ式を用いる。
# 出力ラベルの予測
y_pred = svc_l.predict(X_test_sc)    # predictメソッド：予測ラベルの計算
y_pred
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
# データの可視化
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train)
plt.scatter(X_test[:, 0], X_test[:, 1], c = y_pred, alpha = 0.05)
plt.show()

# %% [markdown]
# #### ハイパーパラメーターCの探索
# 逆正則化パラメータCの値は適切なものを分析者が選ぶ必要があります．<br>
# 10分割交差検証で平均正解率を調べてみましょう．

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

pipe = make_pipeline(StandardScaler(),
                     SVC(C=1.0, kernel="linear")
                    )

scores = cross_val_score(pipe,
                         X = X_train,
                         y = y_train,
                         cv=10)
scores.mean()
# Out:
# 0.9299999999999999

# %% [markdown]
# ## F　カーネルSVM
# ここまでで述べたSVMは線形2値分類を行う手法でした．さらにカーネル法という工夫を施すことによって，非線形の分類器を作ることもできます．
#
# 非線形分類を行うための基本的なアイディアは「データを高次元に送って線形分離し元の空間に引き戻す」というものです．
#
# しかし高次元のデータは一般に計算量が膨大で扱いが困難です．そこでカーネル法という工夫が登場します．
# これはカーネルトリックとも呼ばれ，「**データを高次元に送ることなしに，**高次元に送ったものと同じ結果を得る」ための巧妙な工夫です．
#
# ここからは
#  * 高次元空間での分類が非線形分類につながること
#  * カーネル法
# の二段階で説明をしていきます．

# %% [markdown]
# ## G　高次元空間での分類
# make_circlesデータセットを用いて，高次元空間での分類が非線形の分類を与えることを見ていきましょう．
#
# これは同心円の内側と外側でクラスが分かれているようなデータです．赤と青を直線で分離することが不可能なことは明らかでしょう．

# %%
from sklearn.datasets import make_circles

X , y= make_circles(n_samples=100, factor = 0.5, noise = 0.05)

# %%
plt.scatter(X[y==0,0], X[y==0,1], c="red" )
plt.scatter(X[y==1,0], X[y==1,1], c="blue" )

# %% [markdown]
# ここで，各点ごとに成分の2乗和を計算し，これを3次元目として付け加えます．
#
# すると，付け加えた列は内側ほど小さく，外側ほど大きい値をとることになります．これにより線形分離が可能となります．

# %%
Xsqsum = (X**2).sum(axis=1)
X_high = np.c_[X,Xsqsum]
X_high
# Out:
# array([[-1.02215231, -0.06454637,  1.04896157],
#        [ 0.49437879,  0.18980071,  0.28043469],
#        [ 0.19306203,  0.46232022,  0.25101294],
#        [ 0.54865822, -0.11284793,  0.3137605 ],
#        [ 0.8898745 ,  0.52359566,  1.06602904],
#        [ 0.46374193, -0.29031738,  0.29934076],
#        [ 0.66164063,  0.82222946,  1.11382961],
#        [-0.09774496,  0.55455384,  0.31708404],
#        [-0.13966903,  0.51754682,  0.28736215],
#        [ 0.9764218 , -0.33963996,  1.06875483],
#        [-0.25666021, -0.39427574,  0.22132782],
#        [-0.88996627,  0.61619   ,  1.17173008],
#        [-0.4372574 , -0.20385291,  0.23275004],
#        [ 0.95704264,  0.09675981,  0.92529308],
#        [ 0.6095728 ,  0.05259099,  0.37434481],
#        [-0.44055541,  0.10148628,  0.20438853],
#        [ 1.05510947, -0.14452133,  1.13414242],
#        [-0.77089389, -0.54899931,  0.89567764],
#        [ 0.80956091, -0.62959509,  1.05177884],
#        [ 0.89532478, -0.22152764,  0.85068096],
#        [ 0.23112402, -0.47192396,  0.27613053],
#        [-0.64620921,  0.73023917,  0.95083558],
#        [ 0.50755576, -0.04846955,  0.25996214],
#        [-0.01538261, -0.50385324,  0.25410471],
#        [ 0.57233599,  0.85117404,  1.05206573],
#        [-0.85192326, -0.57378405,  1.05500138],
#        [ 0.55436358, -0.17426843,  0.33768847],
#        [-0.17267384, -0.98658609,  1.00316837],
#        [ 0.15636471, -1.02052508,  1.06592136],
#        [ 0.67484908,  0.67458045,  0.91048006],
#        [-0.09492737,  0.50217887,  0.26119482],
#        [-0.36299571,  0.29145681,  0.21671295],
#        [-0.10483027, -0.42771044,  0.1939256 ],
#        [ 0.98154513, -0.01525742,  0.96366364],
#        [-0.45860158,  0.9464458 ,  1.10607506],
#        [-0.13749127,  0.39829291,  0.17754109],
#        [-0.46598877, -0.8781991 ,  0.98837918],
#        [-0.28898557,  0.41530112,  0.25598768],
#        [-0.87471539,  0.24324151,  0.82429344],
#        [-0.55547825, -0.86206583,  1.05171358],
#        [ 0.34515189,  0.2511789 ,  0.18222067],
#        [-0.11671154, -0.98627861,  0.98636708],
#        [ 0.13860416, -0.54510126,  0.31634649],
#        [ 0.27670099, -0.35614387,  0.20340189],
#        [ 0.27006308,  0.98301054,  1.03924378],
#        [ 0.41498023, -0.90355383,  0.98861811],
#        [-0.93504973, -0.38822839,  1.02503928],
#        [-0.05652425, -0.63707785,  0.40906318],
#        [ 0.9789059 ,  0.19151411,  0.99493442],
#        [ 0.51074956,  0.29799001,  0.34966316],
#        [ 0.20903919, -1.01310365,  1.07007638],
#        [ 0.27631323,  0.43128295,  0.26235399],
#        [ 0.35374905, -0.9413016 ,  1.01118708],
#        [-0.38680819, -0.24345459,  0.20889071],
#        [ 0.44790119,  0.30328622,  0.29259801],
#        [-0.50430715,  0.13735148,  0.27319113],
#        [ 0.30489598,  0.47992093,  0.32328566],
#        [-0.62648479, -0.82941651,  1.08041495],
#        [ 0.40364473,  0.23123261,  0.21639759],
#        [-0.46479132, -0.39952316,  0.37564973],
#        [-0.47844142, -0.2377844 ,  0.28544761],
#        [ 0.09548459,  0.97322368,  0.95628164],
#        [-0.1821249 , -0.52552856,  0.30934974],
#        [-0.20625445,  1.01027738,  1.06320129],
#        [-0.94939182, -0.19739602,  0.94031002],
#        [-0.9959592 , -0.14309563,  1.0124111 ],
#        [-0.57792914,  0.87973242,  1.10793123],
#        [ 0.67654147, -0.81846226,  1.12758883],
#        [-0.71827319, -0.63196212,  0.9152925 ],
#        [-0.25144388, -0.40416641,  0.22657451],
#        [ 0.3032211 , -0.51981867,  0.36215448],
#        [ 0.72212161, -0.73109028,  1.05595262],
#        [ 0.18964633,  0.43817732,  0.22796509],
#        [-0.37822502,  0.3242123 ,  0.24816778],
#        [-0.46554017,  0.06470219,  0.22091402],
#        [ 0.19463349,  0.94566084,  0.93215662],
#        [ 0.5029698 ,  0.98603728,  1.22524813],
#        [-0.69980437,  0.69672508,  0.97515198],
#        [-0.26105858, -0.95721526,  0.98441264],
#        [ 0.45744757, -0.10937731,  0.22122168],
#        [-0.96628099,  0.18849874,  0.96923072],
#        [ 0.65783033, -0.6458565 ,  0.84987136],
#        [-0.01366575,  0.53371066,  0.28503382],
#        [-0.02134869,  0.46790229,  0.21938832],
#        [ 0.81612985,  0.56124734,  0.98106652],
#        [ 0.3278051 , -0.38996709,  0.25953051],
#        [-0.37690945,  0.96912123,  1.0812567 ],
#        [-1.01600601,  0.42303661,  1.21122818],
#        [-0.84648995,  0.51736873,  0.98421564],
#        [-0.41973511, -0.11133223,  0.18857243],
#        [-0.1035318 ,  0.99821804,  1.00715808],
#        [ 0.12568168, -0.47995116,  0.246149  ],
#        [-0.36693373,  0.34571518,  0.25415935],
#        [-0.50640225, -0.01326912,  0.25661931],
#        [-0.20874144,  0.3711068 ,  0.18129325],
#        [ 0.91534064, -0.49248732,  1.08039224],
#        [ 0.41299093, -0.28800405,  0.25350784],
#        [ 1.02047978,  0.43966465,  1.23468398],
#        [-0.46910173, -0.160952  ,  0.24596198],
#        [-0.33994689, -0.43790123,  0.30732137]])

# %%
svc_h = SVC(C=1.0, kernel="linear")
svc_h.fit(X_high, y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# テストデータの入力を生成し、実際に予測させる。
# 格子点上にデータを生成する。
xx, yy = np.meshgrid(
    np.linspace(start = -1.5, stop = 1.5, num = 100), 
    np.linspace(start = -1.5, stop = 1.5, num = 100))
X_test = np.c_[xx.ravel(), yy.ravel(), xx.ravel()**2 + yy.ravel() **2]

# 出力ラベルの予測
y_pred_test = svc_h.predict(X_test)    # predictメソッド：予測ラベルの計算
y_pred_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# データの可視化
plt.scatter(X_high[:, 0], X_high[:, 1], c = y)
plt.scatter(X_test[:, 0], X_test[:, 1], c = y_pred_test, alpha = 0.05)
plt.show()

# %% [markdown]
# ## H　カーネル法
# 上のデモでは散布図の観察により1次元加えることによって非線形の分類を行いました．
# しかし，実際の非線形分類はより複雑な変数変換を行います．
#
# 例えば．2次多項式カーネルと呼ばれるカーネルは2次元の入力を
# $$\phi(x,y)=(1,x,y,x^2,xy,y^2)$$
# という6次元空間に変換します．データに応じた適切な変換を持つカーネルによって特徴量変換を行うことが出来れば，非線形問題を線形問題に落とすことが出来るのではないか信じるのがカーネル法です．

# %% [markdown]
# カーネルには様々な種類がありますが，主に次の2種類がよく使われます．（特徴量の変換関数$\phi$は1次元入力に対する例で書いています。）
# * 多項式カーネル：$\phi(x)=(1,x,x^2,\cdots,x^d)$
# * Gaussカーネル：$\phi(x)=\left(1,\gamma x,\frac{1}{\sqrt{2!}}\gamma^2 x^2,\frac{1}{\sqrt{3!}}\gamma^3 x^3,\cdots\right)$

# %% [markdown]
# ## H　カーネルSVMのsklearnによる実装
# カーネルは`n_neighbors`引数で指定することができ
# * `linear` : 線形カーネル
# * `poly`：多項式カーネル。`degree`引数に次数を渡しましょう。
# * `rbf`：Gaussカーネル。`gamma`引数に適切な値を渡しましょう。

# %%
# デモデータの作成
from sklearn.datasets import make_moons
X_train, y_train = make_moons(n_samples = 100, noise = 0.3, random_state = 2)

# %%
# データの可視化
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train)
plt.show()

# %%
pipe_k = make_pipeline(StandardScaler(),
                     SVC(C=1.0, kernel="rbf", gamma=100.00)
                    )
pipe_k.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('standardscaler',
#                  StandardScaler(copy=True, with_mean=True, with_std=True)),
#                 ('svc',
#                  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                      decision_function_shape='ovr', degree=3, gamma=100.0,
#                      kernel='rbf', max_iter=-1, probability=False,
#                      random_state=None, shrinking=True, tol=0.001,
#                      verbose=False))],
#          verbose=False)

# %%
# テストデータの入力を生成し、実際に予測させる。
# 格子点上にデータを生成する。
xx, yy = np.meshgrid(
    np.linspace(start = -3.1, stop = 3.1, num = 100), 
    np.linspace(start = -2.1, stop = 2.1, num = 100))
X_test = np.c_[xx.ravel(), yy.ravel()]

# 出力ラベルの予測
y_pred = pipe_k.predict(X_test)    # predictメソッド：予測ラベルの計算
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# データの可視化
plt.scatter(X_train[:, 0], X_train[:, 1], c = y_train)
plt.scatter(X_test[:, 0], X_test[:, 1], c = y_pred, alpha = 0.05)
plt.show()

# %% [markdown]
# **演習**
# make_moonデータセットを用いて以下の演習を行ってみましょう．
#  * 線形SVMではうまく判別しきれないことを実験で確認してみてください
#  * 上のデモではC=1.0, gamma=100.0で学習を行いました．ハイパーパラメータを動かして，上のデモより良いパラメータはないか調べてみてください．
