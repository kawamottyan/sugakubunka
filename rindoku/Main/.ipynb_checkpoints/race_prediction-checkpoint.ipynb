# %%
import numpy as np
import pandas as pd

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

# %%
race_df = pd.read_csv("../Scraping/csv/cleaned_race_data.csv")
horse_df = pd.read_csv("../Scraping/csv/cleaned_horse_data.csv")

# %%
race_df.head(1)
# Out:
#         race_id  race_round race_title weather ground_status        date  \
# 0  202205010101           1      3歳未勝利  天候 : 曇       ダート : 良  2022年1月29日
#
#   where_racecourse  total_horse_number  frame_number_first  \
# 0               東京                  16                   1
#
#    horse_number_first  ...  umaren  wide_1_2  wide_1_3  wide_2_3  umatan  \
# 0                   2  ...    1560       580       760       540    3500
#
#    renhuku3  rentan3  is_left_right_straight  distance  hour
# 0      3450    19720                       左      1400    10
#
# [1 rows x 29 columns]

# %%
horse_df.head(1)
# Out:
#         race_id  rank  frame_number  horse_number    horse_id  age  \
# 0  202205010101     1             1             2  2019101749    3
#
#    burden_weight  rider_id  goal_time  half_way_rank  last_time  odds  \
# 0             54      1092       86.3            1.0       37.2   7.9
#
#    popular  horse_weight  tamer_id  owner_id  is_senba  is_mesu  is_osu  \
# 0      4.0         458.0      1106    318803         0        1       0
#
#    horse_weight_dif
# 0               2.0

# %% [markdown]
# # モデル作成

# %%
race_df_for_merge = race_df[['race_id',
                             "race_round",
                             "race_title",
                             "weather",
                             'ground_status',
                             'where_racecourse',
                             'total_horse_number',
                             'is_left_right_straight',]]
merged_horse_df = pd.merge(horse_df, race_df_for_merge, on='race_id')

# %%
merged_horse_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4077 entries, 0 to 4076
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   race_id                 4077 non-null   int64
#  1   rank                    4077 non-null   int64
#  2   frame_number            4077 non-null   int64
#  3   horse_number            4077 non-null   int64
#  4   horse_id                4077 non-null   int64
#  5   age                     4077 non-null   int64
#  6   burden_weight           4077 non-null   int64
#  7   rider_id                4077 non-null   int64
#  8   goal_time               4077 non-null   float64
#  9   half_way_rank           4077 non-null   float64
#  10  last_time               4077 non-null   float64
#  11  odds                    4077 non-null   float64
#  12  popular                 4077 non-null   float64
#  13  horse_weight            4077 non-null   float64
#  14  tamer_id                4077 non-null   int64
#  15  owner_id                4077 non-null   int64
#  16  is_senba                4077 non-null   int64
#  17  is_mesu                 4077 non-null   int64
#  18  is_osu                  4077 non-null   int64
#  19  horse_weight_dif        4077 non-null   float64
#  20  race_round              4077 non-null   int64
#  21  race_title              4077 non-null   object
#  22  weather                 4077 non-null   object
#  23  ground_status           4077 non-null   object
#  24  where_racecourse        4077 non-null   object
#  25  total_horse_number      4077 non-null   int64
#  26  is_left_right_straight  4077 non-null   object
# dtypes: float64(7), int64(15), object(5)
# memory usage: 891.8+ KB

# %%
#merged_horse_df = pd.get_dummies(merged_horse_df, columns=["weather","ground_status",'where_racecourse','is_left_right_straight'])

# %%
merged_horse_df = merged_horse_df.drop(["race_title",
                                        'goal_time',
                                       'half_way_rank',
                                        'last_time',
                                       ], axis=1)

# %%
#LabelEncoder
for column in ['weather',
               'ground_status',
               'where_racecourse',
               'is_left_right_straight']:
    le = LabelEncoder()
    le.fit(merged_horse_df[column])
    merged_horse_df[column] = le.transform(merged_horse_df[column])

# %%
plt.figure(figsize=(15,15)) 
sns.heatmap(merged_horse_df.corr(), square=True, annot=True)
plt.show()

# %%
y = merged_horse_df['rank'].values
X = merged_horse_df.drop('rank', axis=1).values
X_df =merged_horse_df.drop('rank', axis=1)

# %%
X_train, X_test, y_train, y_test =\
            train_test_split(X, y, 
                             test_size=0.2, 
                             random_state=1,
                             stratify=y)

# %%
#弱学習器の作成
tree = DecisionTreeClassifier(criterion='entropy', 
                              max_depth=1,
                              random_state=1)
#アダブーストの作成
ada = AdaBoostClassifier(base_estimator=tree,
                         n_estimators=500, 
                         learning_rate=0.1, 
                         random_state=1)

# %%
#弱学習器の予測
tree = tree.fit(X_train, y_train)
y_train_pred = tree.predict(X_train)
y_test_pred = tree.predict(X_test)
#弱学習器のスコア
tree_train = accuracy_score(y_train, y_train_pred)
tree_test = accuracy_score(y_test, y_test_pred)
print('Decision tree train/test accuracies %.3f/%.3f'
      % (tree_train, tree_test))

#アダブーストの予測
ada = ada.fit(X_train, y_train)
y_train_pred = ada.predict(X_train)
y_test_pred = ada.predict(X_test)
#アダブーストのスコア
ada_train = accuracy_score(y_train, y_train_pred) 
ada_test = accuracy_score(y_test, y_test_pred) 
print('AdaBoost train/test accuracies %.3f/%.3f'
      % (ada_train, ada_test))
# Out:
# Decision tree train/test accuracies 0.800/0.800
# AdaBoost train/test accuracies 0.836/0.806

# %%
fi = ada.feature_importances_  
print('Feature Importances:')
for i, feat in enumerate(X_df.columns):
        print('\t{0:20s} : {1:>.6f}'.format(feat, fi[i]))
# Out:
# Feature Importances:
# 	race_id              : 0.000000
# 	frame_number         : 0.010000
# 	horse_number         : 0.014000
# 	horse_id             : 0.086000
# 	age                  : 0.014000
# 	burden_weight        : 0.026000
# 	rider_id             : 0.078000
# 	odds                 : 0.386000
# 	popular              : 0.020000
# 	horse_weight         : 0.112000
# 	tamer_id             : 0.078000
# 	owner_id             : 0.054000
# 	is_senba             : 0.032000
# 	is_mesu              : 0.000000
# 	is_osu               : 0.000000
# 	horse_weight_dif     : 0.056000
# 	race_round           : 0.008000
# 	weather              : 0.008000
# 	ground_status        : 0.002000
# 	where_racecourse     : 0.000000
# 	total_horse_number   : 0.016000
# 	is_left_right_straight : 0.000000

# %% [markdown]
# # ハイパーパラメータ探索

# %%
param_grid = {
    'n_estimators': [100, 300, 500, 800, 1000],
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.5]
}

ada = AdaBoostClassifier(base_estimator=tree,
                         random_state=1)
grid_search = GridSearchCV(ada, param_grid, cv=5)
gs = grid_search.fit(X_train, y_train)

y_train_pred = gs.predict(X_train)
y_test_pred = gs.predict(X_test)

gs_train = accuracy_score(y_train, y_train_pred) 
gs_test = accuracy_score(y_test, y_test_pred) 
print('GridSearch train/test accuracies %.3f/%.3f'
      % (gs_train, gs_test))

# %%
best_parameters = grid_search.best_params_
best_parameters
